# %%
from pyspark.sql import SparkSession

spark = (SparkSession.builder
  .appName("test-config")
  .config("spark.sql.shuffle.partitions", "50")
  .getOrCreate())

print("autoBroadcastJoinThreshold =", spark.conf.get("spark.sql.autoBroadcastJoinThreshold"))
print("adaptive.enabled =", spark.conf.get("spark.sql.adaptive.enabled"))
print("shuffle.partitions =", spark.conf.get("spark.sql.shuffle.partitions"))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[3], line 6
#       1 from pyspark.sql import SparkSession
#       3 spark = (SparkSession.builder
#       4   .appName("test-config")
#       5   .config("spark.sql.shuffle.partitions", "50")
# ----> 6   .getOrCreate())
#       8 print("autoBroadcastJoinThreshold =", spark.conf.get("spark.sql.autoBroadcastJoinThreshold"))
#       9 print("adaptive.enabled =", spark.conf.get("spark.sql.adaptive.enabled"))
#
# File ~/SourceCode/Python/spark-4.0.1-bin-hadoop3/python/pyspark/sql/session.py:561, in SparkSession.Builder.getOrCreate(self)
#     559     session = SparkSession(sc, options=self._options)
#     560 else:
# --> 561     module = SparkSession._get_j_spark_session_module(session._jvm)
#     562     module.applyModifiableSettings(session._jsparkSession, self._options)
#     563 return session
#
# File ~/SourceCode/Python/spark-4.0.1-bin-hadoop3/python/pyspark/sql/session.py:672, in SparkSession._get_j_spark_session_module(jvm)
#     670 @staticmethod
#     671 def _get_j_spark_session_module(jvm: "JVMView") -> "JavaObject":
# --> 672     return getattr(getattr(jvm, "org.apache.spark.sql.classic.SparkSession$"), "MODULE$")
#
# File ~/SourceCode/Python/spark-4.0.1-bin-hadoop3/python/lib/py4j-0.10.9.9-src.zip/py4j/java_gateway.py:1752, in JVMView.__getattr__(self, name)
#    1749 if name == UserHelpAutoCompletion.KEY:
#    1750     return UserHelpAutoCompletion()
# -> 1752 answer = self._gateway_client.send_command(
#    1753     proto.REFLECTION_COMMAND_NAME +
#    1754     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1755     "\n" + proto.END_COMMAND_PART)
#    1756 if answer == proto.SUCCESS_PACKAGE:
#    1757     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File ~/SourceCode/Python/spark-4.0.1-bin-hadoop3/python/lib/py4j-0.10.9.9-src.zip/py4j/java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)   1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File ~/SourceCode/Python/spark-4.0.1-bin-hadoop3/python/lib/py4j-0.10.9.9-src.zip/py4j/clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File ~/SourceCode/Python/spark-4.0.1-bin-hadoop3/python/lib/py4j-0.10.9.9-src.zip/py4j/clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File ~/SourceCode/Python/spark-4.0.1-bin-hadoop3/python/lib/py4j-0.10.9.9-src.zip/py4j/clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [Errno 61] Connection refused
